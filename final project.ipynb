# %%
import pandas as pd

# %%
df=pd.read_csv('CHDdata.csv')

# %%
df.head()
# Out:
#    sbp  tobacco   ldl  adiposity  famhist  typea  obesity  alcohol  age  chd
# 0  160    12.00  5.73      23.11  Present     49    25.30    97.20   52    1
# 1  144     0.01  4.41      28.61   Absent     55    28.87     2.06   63    1
# 2  118     0.08  3.48      32.28  Present     52    29.14     3.81   46    0
# 3  170     7.50  6.41      38.03  Present     51    31.99    24.26   58    1
# 4  134    13.60  3.50      27.78  Present     60    25.99    57.34   49    1

# %% [markdown]
# sbp: systolic blood pressure is the force exerted by the blood against the walls of the arteries when the heart beats. High blood pressure can contribute to the development of heart disease.
# tobacco: smoking tobacco is a known risk factor for heart disease.
# ldl: low-density lipoprotein (LDL) is a type of cholesterol that can build up in the arteries and contribute to the development of heart disease.
# adiposity: adiposity is a measure of body fat. Excess body fat is a risk factor for heart disease.
# famhist: family history of heart disease can increase an individual's risk for developing heart disease.
# typea: Type A behavior pattern is a personality trait characterized by competitiveness, impatience, and a sense of urgency. Some research has linked Type A behavior with an increased risk for heart disease.
# obesity: obesity, which is defined as having a body mass index (BMI) of 30 or higher, is a risk factor for heart disease.
# alcohol: heavy alcohol consumption can increase the risk for heart disease.
# age: as individuals age, their risk for heart disease increases.
# chd: presence or absence of coronary heart disease.

# %% [markdown]
# ## checking if any null values are there or not

# %%
df.isnull()
# Out:
#        sbp  tobacco    ldl  adiposity  famhist  typea  obesity  alcohol  \
# 0    False    False  False      False    False  False    False    False
# 1    False    False  False      False    False  False    False    False
# 2    False    False  False      False    False  False    False    False
# 3    False    False  False      False    False  False    False    False
# 4    False    False  False      False    False  False    False    False
# ..     ...      ...    ...        ...      ...    ...      ...      ...
# 457  False    False  False      False    False  False    False    False
# 458  False    False  False      False    False  False    False    False
# 459  False    False  False      False    False  False    False    False
# 460  False    False  False      False    False  False    False    False
# 461  False    False  False      False    False  False    False    False
#
#        age    chd
# 0    False  False
# 1    False  False
# 2    False  False
# 3    False  False
# ...

# %%
df.isnull().sum()
# Out:
# sbp          0
# tobacco      0
# ldl          0
# adiposity    0
# famhist      0
# typea        0
# obesity      0
# alcohol      0
# age          0
# chd          0
# dtype: int64

# %% [markdown]
# ## observation: we dont have any null values

# %%
## info about data set
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 462 entries, 0 to 461
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sbp        462 non-null    int64
#  1   tobacco    462 non-null    float64
#  2   ldl        462 non-null    float64
#  3   adiposity  462 non-null    float64
#  4   famhist    462 non-null    object
#  5   typea      462 non-null    int64
#  6   obesity    462 non-null    float64
#  7   alcohol    462 non-null    float64
#  8   age        462 non-null    int64
#  9   chd        462 non-null    int64
# dtypes: float64(5), int64(4), object(1)
# memory usage: 36.2+ KB

# %%
df.columns
# Out:
# Index(['sbp', 'tobacco', 'ldl', 'adiposity', 'famhist', 'typea', 'obesity',
#        'alcohol', 'age', 'chd'],
#       dtype='object')

# %%
df.describe()
# Out:
#               sbp     tobacco         ldl   adiposity       typea     obesity  \
# count  462.000000  462.000000  462.000000  462.000000  462.000000  462.000000
# mean   138.326840    3.635649    4.740325   25.406732   53.103896   26.044113
# std     20.496317    4.593024    2.070909    7.780699    9.817534    4.213680
# min    101.000000    0.000000    0.980000    6.740000   13.000000   14.700000
# 25%    124.000000    0.052500    3.282500   19.775000   47.000000   22.985000
# 50%    134.000000    2.000000    4.340000   26.115000   53.000000   25.805000
# 75%    148.000000    5.500000    5.790000   31.227500   60.000000   28.497500
# max    218.000000   31.200000   15.330000   42.490000   78.000000   46.580000
#
#           alcohol         age         chd
# count  462.000000  462.000000  462.000000
# mean    17.044394   42.816017    0.346320
# std     24.481059   14.608956    0.476313
# min      0.000000   15.000000    0.000000
# 25%      0.510000   31.000000    0.000000
# ...

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(10,6.27)})

# %%
sns.countplot(x='age',data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
df.head()
# Out:
#    sbp  tobacco   ldl  adiposity  famhist  typea  obesity  alcohol  age  chd
# 0  160    12.00  5.73      23.11  Present     49    25.30    97.20   52    1
# 1  144     0.01  4.41      28.61   Absent     55    28.87     2.06   63    1
# 2  118     0.08  3.48      32.28  Present     52    29.14     3.81   46    0
# 3  170     7.50  6.41      38.03  Present     51    31.99    24.26   58    1
# 4  134    13.60  3.50      27.78  Present     60    25.99    57.34   49    1

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['famhist']=le.fit_transform(df['famhist'])
df
#one hot encoding
## coverting object columns into decimal format
# Out:
#      sbp  tobacco    ldl  adiposity  famhist  typea  obesity  alcohol  age  \
# 0    160    12.00   5.73      23.11        1     49    25.30    97.20   52
# 1    144     0.01   4.41      28.61        0     55    28.87     2.06   63
# 2    118     0.08   3.48      32.28        1     52    29.14     3.81   46
# 3    170     7.50   6.41      38.03        1     51    31.99    24.26   58
# 4    134    13.60   3.50      27.78        1     60    25.99    57.34   49
# ..   ...      ...    ...        ...      ...    ...      ...      ...  ...
# 457  214     0.40   5.98      31.72        0     64    28.45     0.00   58
# 458  182     4.20   4.41      32.10        0     52    28.61    18.72   52
# 459  108     3.00   1.59      15.23        0     40    20.09    26.64   55
# 460  118     5.40  11.61      30.79        0     64    27.35    23.97   40
# 461  132     0.00   4.82      33.41        1     62    14.70     0.00   46
#
#      chd
# 0      1
# 1      1
# 2      0
# 3      1
# 4      1
# ...

# %% [markdown]
# co realtion -relation between two columns

# %%
# Plot a scatter plot between two variables
sns.scatterplot(x='age', y='chd', data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='chd'>

# %%
sns.boxplot(x='age', y='chd', data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='chd'>

# %%
sns.countplot(x='chd',data=df)
# Out:
# <AxesSubplot:xlabel='chd', ylabel='count'>

# %%
# Plot a histogram of a variable
sns.histplot(x='age', data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
# Plot a pairplot of multiple variables
sns.pairplot(df, vars=['sbp', 'tobacco', 'ldl', 'adiposity', 'famhist', 'typea', 'obesity',
       'alcohol', 'age'], hue='chd')
#equal distrubted or not

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 462 entries, 0 to 461
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sbp        462 non-null    int64
#  1   tobacco    462 non-null    float64
#  2   ldl        462 non-null    float64
#  3   adiposity  462 non-null    float64
#  4   famhist    462 non-null    int32
#  5   typea      462 non-null    int64
#  6   obesity    462 non-null    float64
#  7   alcohol    462 non-null    float64
#  8   age        462 non-null    int64
#  9   chd        462 non-null    int64
# dtypes: float64(5), int32(1), int64(4)
# memory usage: 34.4 KB

# %%
df['chd'].value_counts()
# Out:
# 0    302
# 1    160
# Name: chd, dtype: int64

# %%
# equal sampling
cls_0=df[df['chd']==0]
cls_1=df[df['chd']==1]
cls_1=cls_1.sample(1500,replace=True)
cls_0=cls_0.sample(1500,replace=True)
df=pd.concat([cls_0,cls_1],axis=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3000 entries, 49 to 293
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sbp        3000 non-null   int64
#  1   tobacco    3000 non-null   float64
#  2   ldl        3000 non-null   float64
#  3   adiposity  3000 non-null   float64
#  4   famhist    3000 non-null   int32
#  5   typea      3000 non-null   int64
#  6   obesity    3000 non-null   float64
#  7   alcohol    3000 non-null   float64
#  8   age        3000 non-null   int64
#  9   chd        3000 non-null   int64
# dtypes: float64(5), int32(1), int64(4)
# memory usage: 246.1 KB

# %%
df
# Out:
#      sbp  tobacco   ldl  adiposity  famhist  typea  obesity  alcohol  age  chd
# 49   126     3.80  3.88      31.79        0     57    30.53     0.00   30    0
# 266  118     0.12  4.16       9.37        0     57    19.61     0.00   17    0
# 459  108     3.00  1.59      15.23        0     40    20.09    26.64   55    0
# 294  134     0.00  5.63      29.12        0     68    32.33     2.02   34    0
# 319  142     3.72  4.24      32.57        0     52    24.98     7.61   51    0
# ..   ...      ...   ...        ...      ...    ...      ...      ...  ...  ...
# 131  132     2.00  3.08      35.39        0     45    31.44    79.82   58    1
# 246  136     0.40  3.91      21.10        1     63    22.30     0.00   56    1
# 391  154     2.40  5.63      42.17        1     59    35.07    12.86   50    1
# 453  124     1.60  7.22      39.68        1     36    31.50     0.00   51    1
# 293  170     2.60  7.22      28.69        1     71    27.87    37.65   56    1
#
# ...

# %%
df.to_csv('final.csv')

# %%
df
# Out:
#      sbp  tobacco   ldl  adiposity  famhist  typea  obesity  alcohol  age  chd
# 49   126     3.80  3.88      31.79        0     57    30.53     0.00   30    0
# 266  118     0.12  4.16       9.37        0     57    19.61     0.00   17    0
# 459  108     3.00  1.59      15.23        0     40    20.09    26.64   55    0
# 294  134     0.00  5.63      29.12        0     68    32.33     2.02   34    0
# 319  142     3.72  4.24      32.57        0     52    24.98     7.61   51    0
# ..   ...      ...   ...        ...      ...    ...      ...      ...  ...  ...
# 131  132     2.00  3.08      35.39        0     45    31.44    79.82   58    1
# 246  136     0.40  3.91      21.10        1     63    22.30     0.00   56    1
# 391  154     2.40  5.63      42.17        1     59    35.07    12.86   50    1
# 453  124     1.60  7.22      39.68        1     36    31.50     0.00   51    1
# 293  170     2.60  7.22      28.69        1     71    27.87    37.65   56    1
#
# ...

# %%
df['chd'].value_counts()
# Out:
# 0    1500
# 1    1500
# Name: chd, dtype: int64

# %%
## dividing dependent and independent varialbes
X = df.drop('chd',axis=1)
y = df['chd']

# %%
X
# Out:
#      sbp  tobacco   ldl  adiposity  famhist  typea  obesity  alcohol  age
# 49   126     3.80  3.88      31.79        0     57    30.53     0.00   30
# 266  118     0.12  4.16       9.37        0     57    19.61     0.00   17
# 459  108     3.00  1.59      15.23        0     40    20.09    26.64   55
# 294  134     0.00  5.63      29.12        0     68    32.33     2.02   34
# 319  142     3.72  4.24      32.57        0     52    24.98     7.61   51
# ..   ...      ...   ...        ...      ...    ...      ...      ...  ...
# 131  132     2.00  3.08      35.39        0     45    31.44    79.82   58
# 246  136     0.40  3.91      21.10        1     63    22.30     0.00   56
# 391  154     2.40  5.63      42.17        1     59    35.07    12.86   50
# 453  124     1.60  7.22      39.68        1     36    31.50     0.00   51
# 293  170     2.60  7.22      28.69        1     71    27.87    37.65   56
#
# [3000 rows x 9 columns]

# %% [markdown]
# min max scalar 0-1
# standard scalar any range based on data

# %% [markdown]
# stratufy=y
# random state

# %%
import sys
# !{sys.executable} -m pip install xgboost

# %% [markdown]
# # train test data split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=0,stratify=y)
#stratify same proportion of train and test data
#random_state 
# If you don't specify the random_state in the code, then every time you run(execute) your code a new random value is generated and the train and test datasets would have different values each time.

# However, if a fixed value is assigned like random_state = 0 or 1 or 42 or any other integer then no matter how many times you execute your code the result would be the same .i.e, same values in train and test datasets.

# %%
# import math
# from sklearn import metrics

# #metrics to find accuracy of continous variables
# print('Mean Abs value:' ,metrics.mean_absolute_error(y_test,predictions))
# print('Mean squared value:',metrics.mean_squared_error(y_test,predictions))
# print('root mean squared error value:',math.sqrt(metrics.mean_squared_error(y_test,predictions)))

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
model = LogisticRegression(max_iter=100000)
model.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=100000)

# %% [markdown]
# # LogisticRegression metrics

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
predictions= model.predict(X_test)
percentage=model.score(X_test,y_test)
res=confusion_matrix(y_test,predictions)
print("validation confusion matrix")
print(res)
print(classification_report(y_test, predictions))
# check the accuracy on the training set
print('training accuracy = '+str(model.score(X_train, y_train)*100))
print('testing accuracy = '+str(model.score(X_test, y_test)*100))
print("Accuracy:", (metrics.accuracy_score(y_test, predictions))*100)
# Out:
# validation confusion matrix
# [[210  90]
#  [ 65 235]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.70      0.73       300
#            1       0.72      0.78      0.75       300
#
#     accuracy                           0.74       600
#    macro avg       0.74      0.74      0.74       600
# weighted avg       0.74      0.74      0.74       600
#
# training accuracy = 73.04166666666667
# testing accuracy = 74.16666666666667
# Accuracy: 74.16666666666667

# %% [markdown]
# # support vector classifer

# %%
from sklearn.svm import SVC

# %%
model = SVC()
model.fit(X_train,y_train)
# Out:
# SVC()

# %% [markdown]
# # support vector classifer metrics

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
predictions= model.predict(X_test)
percentage=model.score(X_test,y_test)
res=confusion_matrix(y_test,predictions)
print("validation confusion matrix")
print(res)
print(classification_report(y_test, predictions))
# check the accuracy on the training set
print('training accuracy = '+str(model.score(X_train, y_train)*100))
print('testing accuracy = '+str(model.score(X_test, y_test)*100))
print("Accuracy:", (metrics.accuracy_score(y_test, predictions))*100)
# Out:
# validation confusion matrix
# [[187 113]
#  [ 64 236]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.62      0.68       300
#            1       0.68      0.79      0.73       300
#
#     accuracy                           0.70       600
#    macro avg       0.71      0.70      0.70       600
# weighted avg       0.71      0.70      0.70       600
#
# training accuracy = 70.29166666666666
# testing accuracy = 70.5
# Accuracy: 70.5

# %% [markdown]
# #  RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
# n_estimeter means no of trees 
model = RandomForestClassifier(n_estimators=100)
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# #  RandomForestClassifier metrics

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
predictions= model.predict(X_test)
percentage=model.score(X_test,y_test)
res=confusion_matrix(y_test,predictions)
print("validation confusion matrix")
print(res)
print(classification_report(y_test, predictions))
# check the accuracy on the training set
print('training accuracy = '+str(model.score(X_train, y_train)*100))
print('testing accuracy = '+str(model.score(X_test, y_test)*100))
print("Accuracy:", (metrics.accuracy_score(y_test, predictions))*100)
# Out:
# validation confusion matrix
# [[298   2]
#  [  0 300]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       300
#            1       0.99      1.00      1.00       300
#
#     accuracy                           1.00       600
#    macro avg       1.00      1.00      1.00       600
# weighted avg       1.00      1.00      1.00       600
#
# training accuracy = 100.0
# testing accuracy = 99.66666666666667
# Accuracy: 99.66666666666667

# %% [markdown]
# # feature_importances

# %%
importances = model.feature_importances_

# create a dataframe of feature importances
feature_importances = pd.DataFrame({'feature': X.columns, 'importance': importances})

# sort the features by importance in descending order
feature_importances = feature_importances.sort_values(by='importance', ascending=False).reset_index(drop=True)

# print the top 3 most important features
print("Feature 1: {} ({})".format(feature_importances['feature'][0], feature_importances['importance'][0]))
print("Feature 2: {} ({})".format(feature_importances['feature'][1], feature_importances['importance'][1]))
print("Feature 3: {} ({})".format(feature_importances['feature'][2], feature_importances['importance'][2]))
# Out:
# Feature 1: age (0.17627364936021675)
# Feature 2: tobacco (0.15207491556978697)
# Feature 3: ldl (0.11888791753054255)

# %%
feature_importances
# Out:
#      feature  importance
# 0        age    0.176274
# 1    tobacco    0.152075
# 2        ldl    0.118888
# 3  adiposity    0.117629
# 4        sbp    0.099563
# 5      typea    0.098904
# 6    obesity    0.096373
# 7    alcohol    0.090014
# 8    famhist    0.050280

# %% [markdown]
# ## ensemble modeling
# Ensemble learning refers to a machine learning approach in which the predictions from multiple models are merged to enhance the accuracy and resilience of the ultimate forecast.

# %%
import xgboost
from xgboost import XGBClassifier
model=XGBClassifier()
model.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
predictions= model.predict(X_test)
percentage=model.score(X_test,y_test)
res=confusion_matrix(y_test,predictions)
print("validation confusion matrix")
print(res)
print(classification_report(y_test, predictions))
# check the accuracy on the training set
print('training accuracy = '+str(model.score(X_train, y_train)*100))
print('testing accuracy = '+str(model.score(X_test, y_test)*100))
print("Accuracy:", (metrics.accuracy_score(y_test, predictions))*100)
# Out:
# validation confusion matrix
# [[297   3]
#  [  0 300]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       300
#            1       0.99      1.00      1.00       300
#
#     accuracy                           0.99       600
#    macro avg       1.00      0.99      0.99       600
# weighted avg       1.00      0.99      0.99       600
#
# training accuracy = 100.0
# testing accuracy = 99.5
# Accuracy: 99.5

# %%
## observation the above model is goes under overfitting which means low bais and high variance
